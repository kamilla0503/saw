# %%
import matplotlib.pyplot as plt
import random
import numpy as np

import pandas as pd
from matplotlib.ticker import LogFormatter 
from scipy.optimize import curve_fit
from pathlib import Path
import matplotlib.colors
from matplotlib import ticker, cm
import pickle

from scipy.stats import norm

# %%
 
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


data_np = np.loadtxt("Ising/Geometry_Results/R2_distributions/R2_0.830000_0.000000_2000.txt", skiprows=2)
plt.plot(np.sqrt(data_np[:, 0]), data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.83")
 
data_np = np.loadtxt("Ising/Geometry_Results/R2_distributions/R2_0.832000_0.000000_2000.txt", skiprows=2)
plt.plot(np.sqrt(data_np[:, 0]), data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.832")


data_np = np.loadtxt("Ising/Geometry_Results/R2_distributions/R2_0.833000_0.000000_2000.txt", skiprows=2)
plt.plot(np.sqrt(data_np[:, 0]), data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.833")
 

    
data_np = np.loadtxt("Ising/Geometry_Results/R2_distributions/R2_0.834000_0.000000_2000.txt", skiprows=2)
plt.plot(np.sqrt(data_np[:, 0]), data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.834")
 

 
plt.title("Distribution of R^2 in Ising ISAW for N = 2000 ", fontsize=22)

plt.xlabel(r'$ |R| $', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)

# %%
 
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


data_np = np.loadtxt("Ising/Geometry_Results/R2_distributions/R2_0.662000_0.000000_2000_Homopolymer.txt", skiprows=2)
#plt.plot(np.sqrt(data_np[:, 0]), data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.62")
 
data_np = np.loadtxt("Ising/Geometry_Results/R2_distributions/R2_0.664000_0.000000_2000_Homopolymer.txt", skiprows=2)
#plt.plot(np.sqrt(data_np[:, 0]), data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.664")


data_np = np.loadtxt("Ising/Geometry_Results/R2_distributions/R2_0.666000_0.000000_2000_Homopolymer.txt", skiprows=2)
#plt.plot(np.sqrt(data_np[:, 0]), data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.666")
 

    
data_np = np.loadtxt("Ising/Geometry_Results/R2_distributions/R2_0.668000_0.000000_2000_Homopolymer.txt", skiprows=2)
plt.plot(np.sqrt(data_np[:, 0]), data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.668")
 

 
plt.title("Distribution of R^2 in   ISAW for N = 2000 ", fontsize=22)

plt.xlabel(r'$ |R| $', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)

# %%
fig = plt.figure(figsize=(13, 10))
ax = fig.add_subplot(111)


data_np = np.loadtxt("Ising/Geometry_Results/R2_distributions/R2_0.000000_0.000000_2000_Homopolymer.txt", skiprows=2)
plt.plot(np.sqrt(data_np[:, 0]), data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0")
 
 

data_np = np.loadtxt("Ising/Geometry_Results/R2_distributions/R2_0.666000_0.000000_2000_Homopolymer.txt", skiprows=2)
plt.plot(np.sqrt(data_np[:, 0]), data_np[:,1]/np.sum( data_np[:,1]) , "o", label = r"J = 0.666")
 


 
plt.title("Distribution of R^2 in   ISAW for N = 2000 ", fontsize=22)

plt.xlabel(r'$ |R| $', fontsize = 22)
#plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-0.02, 0.7)

plt.grid()

plt.legend(loc="best", fontsize=20)
