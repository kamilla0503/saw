# %%
import matplotlib.pyplot as plt
import random
import numpy as np
import pandas as pd
from matplotlib.ticker import LogFormatter 
from scipy.optimize import curve_fit
from pathlib import Path
import matplotlib.colors
from matplotlib import ticker, cm
from scipy.stats import binom_test
#%matplotlib notebook

# %%
N = 149

filename = "HP_simulations/Main_Simulations/counts_mags_hp_moresteps_1."+str(2)+"00000_higher_hpc.txt"
results = np.loadtxt(filename, skiprows=5) 
results=results[results[:,0]==N] 
meanm = np.sum(results[:,1]*results[:,2]/N)/np.sum(results[:,2])
meansq = np.sum(np.square(results[:,1])*results[:,2])/np.sum(results[:,2])

 

filename = "HP_simulations/Main_Simulations/counts_hp_moresteps_1."+str(2)+"00000_higher_hpc.txt"
results_m = np.loadtxt(filename, skiprows=9) 
results_m=results_m[results_m[:,0]==N]
meanm_m = np.sum(results_m[:,1]*results_m[:,2])/np.sum(results_m[:,2])
meansq_m = np.sum(np.square(results_m[:,1])*results_m[:,2])/np.sum(results_m[:,2])

 

filename = "HP_simulations/Main_Simulations/counts_mags_hp_moresteps_1."+str(4)+"00000_higher_hpc.txt"
results14 = np.loadtxt(filename, skiprows=5) 
results14=results14[results14[:,0]==N] 
meanm14 = np.sum(results14[:,1]*results14[:,2]/N)/np.sum(results14[:,2])
meansq = np.sum(np.square(results14[:,1])*results14[:,2])/np.sum(results14[:,2])

 

filename = "HP_simulations/Main_Simulations/counts_hp_moresteps_1."+str(4)+"00000_higher_hpc.txt"
results_m14 = np.loadtxt(filename, skiprows=9) 
results_m14=results_m14[results_m14[:,0]==N]
meanm_m = np.sum(results_m14[:,1]*results_m14[:,2])/np.sum(results_m14[:,2])
meansq_m = np.sum(np.square(results_m14[:,1])*results_m14[:,2])/np.sum(results_m14[:,2])



filename = "HP_simulations/Main_Simulations/counts_mags_hp_moresteps_1."+str(0)+"00000_higher_hpc.txt"
results10 = np.loadtxt(filename, skiprows=5) 
results10=results10[results10[:,0]==N] 
meanm10 = np.sum(results10[:,1]*results10[:,2]/N)/np.sum(results10[:,2])
meansq = np.sum(np.square(results10[:,1])*results10[:,2])/np.sum(results10[:,2])

 

filename = "HP_simulations/Main_Simulations/counts_hp_moresteps_1."+str(0)+"00000_higher_hpc.txt"
results_m10 = np.loadtxt(filename, skiprows=9) 
results_m10=results_m10[results_m10[:,0]==N]
meanm_m = np.sum(results_m10[:,1]*results_m10[:,2])/np.sum(results_m10[:,2])
meansq_m = np.sum(np.square(results_m10[:,1])*results_m10[:,2])/np.sum(results_m10[:,2])



filename = "HP_simulations/Main_Simulations/counts_mags_hp_moresteps_0."+str(7)+"00000_higher_hpc.txt"
results7 = np.loadtxt(filename, skiprows=5) 
results7=results7[results7[:,0]==N] 
meanm10 = np.sum(results10[:,1]*results10[:,2]/N)/np.sum(results10[:,2])
meansq = np.sum(np.square(results10[:,1])*results10[:,2])/np.sum(results10[:,2])

 

filename = "HP_simulations/Main_Simulations/counts_hp_moresteps_0."+str(7)+"00000_higher_hpc.txt"
results_m7 = np.loadtxt(filename, skiprows=9) 
results_m7=results_m7[results_m7[:,0]==N]
meanm_m = np.sum(results_m10[:,1]*results_m10[:,2])/np.sum(results_m10[:,2])
meansq_m = np.sum(np.square(results_m10[:,1])*results_m10[:,2])/np.sum(results_m10[:,2])


filename = "HP_simulations/Main_Simulations/counts_mags_hp_moresteps_0."+str(4)+"00000_higher_hpc.txt"
results3 = np.loadtxt(filename, skiprows=5) 
results3=results3[results3[:,0]==N] 
meanm10 = np.sum(results10[:,1]*results10[:,2]/N)/np.sum(results10[:,2])
meansq = np.sum(np.square(results10[:,1])*results10[:,2])/np.sum(results10[:,2])
 

filename = "HP_simulations/Main_Simulations/counts_hp_moresteps_0."+str(3)+"00000_higher_hpc.txt"
results_m3 = np.loadtxt(filename, skiprows=9) 
results_m3=results_m3[results_m3[:,0]==N]
meanm_m = np.sum(results_m10[:,1]*results_m10[:,2])/np.sum(results_m10[:,2])
meansq_m = np.sum(np.square(results_m10[:,1])*results_m10[:,2])/np.sum(results_m10[:,2])

filename = "HP_simulations/Main_Simulations/counts_mags_hp_moresteps_0."+str(0)+"00000_higher_hpc.txt"
results0 = np.loadtxt(filename, skiprows=5) 
results0=results0[results0[:,0]==N] 
meanm10 = np.sum(results10[:,1]*results10[:,2]/N)/np.sum(results10[:,2])
meansq = np.sum(np.square(results10[:,1])*results10[:,2])/np.sum(results10[:,2])

 

filename = "HP_simulations/Main_Simulations/counts_hp_moresteps_0."+str(0)+"00000_higher_hpc.txt"
results_m0 = np.loadtxt(filename, skiprows=9) 
results_m0=results_m0[results_m0[:,0]==N]
meanm_m = np.sum(results_m10[:,1]*results_m10[:,2])/np.sum(results_m10[:,2])
meansq_m = np.sum(np.square(results_m10[:,1])*results_m10[:,2])/np.sum(results_m10[:,2])

# %%
plt.figure(figsize=(20,10))
#plt.subplot(1,2,1)

plt.plot(results0[:,1],  results0[:,2]/np.sum(results0[:,2]) , "s", c = "g", lw=9, label = r"$ \epsilon_b = 0.0 $)")


#plt.plot(results3[:,1],  results3[:,2]/np.sum(results3[:,2]) , "*", c = "b", lw=9, label = r"$ \epsilon_b = 0.4 $)")

plt.plot(results7[:,1],  results7[:,2]/np.sum(results7[:,2]) , "o", c = "purple", lw=9, label = r"$ \epsilon_b = 0.7 $)")

plt.plot(results10[:,1],  results10[:,2]/np.sum(results10[:,2]) , "d", c = "aqua", lw=9, label = r"$ \epsilon_b = 1.0 $)")


plt.plot(results[:,1],  results[:,2]/np.sum(results[:,2]) , "D", c = "tomato", lw=9, label = r"$ \epsilon_b = 1.2 $)")

plt.plot(results14[:,1],  results14[:,2]/np.sum(results14[:,2]) , "s", c = "magenta", lw=9, label = r"$ \epsilon_b = 1.4 $)")
 
plt.plot([75], [0.0665], "*", ms=14,c="k")

plt.xlabel(r"The Number of H-monomers", fontsize = 20)
plt.ylabel(r"  ", fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
 

plt.legend(loc="best", fontsize=20)


#plt.savefig("/home/kamilla/SAWs/Bachelor thesis/img/h_distr.png")

# %%
plt.figure(figsize=(20,10))
 

plt.plot(results_m0[:,1],  results_m0[:,2]/np.sum(results_m0[:,2]) , "s", c = "g", lw=9, label = r"$ \epsilon_b = 0.0 $)")


#plt.plot(results3[:,1],  results3[:,2]/np.sum(results3[:,2]) , "*", c = "b", lw=9, label = r"$ \epsilon_b = 0.4 $)")

plt.plot(results_m7[:,1],  results_m7[:,2]/np.sum(results_m7[:,2]) , "o", c = "purple", lw=9, label = r"$ \epsilon_b = 0.7 $)")

plt.plot(results_m10[:,1],  results_m10[:,2]/np.sum(results_m10[:,2]) , "d", c = "aqua", lw=9, label = r"$ \epsilon_b = 1.0 $)")


plt.plot(results_m[:,1],  results_m[:,2]/np.sum(results_m[:,2]) , "D", c = "tomato", lw=9, label = r"$ \epsilon_b = 1.2 $)")

plt.plot(results_m14[:,1],  results_m14[:,2]/np.sum(results_m14[:,2]) , "s", c = "magenta", lw=9, label = r"$ \epsilon_b = 1.4 $)")
 

plt.xlabel(r"The Number of H-H topological contacts", fontsize = 20)
plt.ylabel(r"  ", fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
#plt.title('Распределение Н ', fontsize=20)

plt.legend(loc="best", fontsize=20)


#plt.savefig("/home/kamilla/SAWs/Bachelor thesis/img/hc_distr.png")
