# %%
import matplotlib.pyplot as plt
import random
import numpy as np

import pandas as pd
from matplotlib.ticker import LogFormatter 
from scipy.optimize import curve_fit
from pathlib import Path
import matplotlib.colors
from matplotlib import ticker, cm
import pickle

# %% [markdown]
# ### $\epsilon_b=0.0$  (Non-interacting SAW)

# %%
 
    
    
with open('Ising/radiues0.pickle', 'rb') as f:
    x = pickle.load(f)

fig = plt.figure(figsize=(8, 7))
ax = fig.add_subplot(111)

results = np.loadtxt("Ising/Calcs_1/Radius_0.000000_0_higher_hpc.txt", skiprows=3)
n_saw = results[:,0]
mean_r = results[:,1]

plt.title(r"End-to-end distance $R_e^2$", fontsize=24)
plt.errorbar( n_saw[:11], mean_r[:11] , yerr=results[:11,2], fmt="o", ms=10, c="k",label =  "Monte-Carlo data")

plt.plot(np.arange(4, 10), x, "s",c = "b", ms=14, alpha=0.45, label = "Exact enumeration")

ax.set_xticks(np.arange(2, 13, 2))

plt.xlabel("N", fontsize = 24)
plt.ylabel( r"$R_e^2$" , fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 


plt.legend(loc="best", fontsize=20)

plt.savefig("/home/kamilla/Lattice_models/img/endMc0.png")

# %%
results = np.loadtxt("Ising/Calcs_1/Radius_0.000000_0_higher_hpc.txt", skiprows=3)
n_saw = results[:,0]
mean_r = results[:,1]


fig = plt.figure(figsize=(8, 7))
ax = fig.add_subplot(111)
 
#plt.xlim(-1, 21)
#plt.ylim(-1, 65)
plt.title(r"End-to-end distance $R_e^2$", fontsize=24)
plt.errorbar( n_saw[:700:5], mean_r[:700:5] , yerr=results[:700:5,2], fmt=".", c="k",label =  "Monte-Carlo data")

ax.set_xticks(np.arange(0, 701, 100))

plt.xlabel("N", fontsize = 24)
plt.ylabel( r"$R_e^2$" , fontsize=21)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 


plt.legend(loc="best", fontsize=20)

plt.savefig("/home/kamilla/Lattice_models/img/endEE0.png")

# %% [markdown]
# ### $\epsilon_b=0.5$

# %%
 

with open('Ising/radiues10.5.pickle', 'rb') as f:
    x = pickle.load(f)

fig = plt.figure(figsize=(8, 7))
ax = fig.add_subplot(111)

results = np.loadtxt("Ising/Calcs_1/Radius_0.500000_0_higher_hpc.txt", skiprows=3)
n_saw = results[:,0]
mean_r = results[:,1]

plt.title(r"End-to-end distance $R_e^2$", fontsize=24)
plt.errorbar( n_saw[:11], mean_r[:11] , yerr=results[:11,2], fmt="o", ms=10, c="k",label =  "Monte-Carlo data")

plt.plot(np.arange(4, 10), x, "s",c = "b", ms=14, alpha=0.45, label = "Exact enumeration")

ax.set_xticks(np.arange(2, 13, 2))

plt.xlabel("N", fontsize = 24)
plt.ylabel( r"$R_e^2$" , fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 


plt.legend(loc="best", fontsize=20)

#plt.savefig("/home/kamilla/Lattice_models/img/endMc05.png")

# %%
results = np.loadtxt("Ising/Calcs_1/Radius_0.500000_0_higher_hpc.txt", skiprows=3)
n_saw = results[:,0]
mean_r = results[:,1]


fig = plt.figure(figsize=(8, 7))
ax = fig.add_subplot(111)
 
#plt.xlim(-1, 21)
#plt.ylim(-1, 65)
plt.title(r"End-to-end distance $R_e^2$", fontsize=24)
plt.errorbar( n_saw[:700:5], mean_r[:700:5] , yerr=results[:700:5,2], fmt=".", c="k",label =  "Monte-Carlo data")

ax.set_xticks(np.arange(0, 701, 100))

plt.xlabel("N", fontsize = 24)
plt.ylabel( r"$R_e^2$" , fontsize=21)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 


plt.legend(loc="best", fontsize=20)

plt.savefig("/home/kamilla/Lattice_models/img/endEE05.png")

# %% [markdown]
# ### $\epsilon_b=0.8 $

# %%
with open('Ising/radiues10.8.pickle', 'rb') as f:
    x = pickle.load(f)

fig = plt.figure(figsize=(8, 7))
ax = fig.add_subplot(111)

results = np.loadtxt("Ising/Calcs_1/Radius_0.800000_0_higher_hpc.txt", skiprows=3)
n_saw = results[:,0]
mean_r = results[:,1]

plt.title(r"End-to-end distance $R_e^2$", fontsize=24)
plt.errorbar( n_saw[:11], mean_r[:11] , yerr=results[:11,2], fmt="o", ms=10, c="k",label =  "Monte-Carlo data")

plt.plot(np.arange(4, 10), x, "s",c = "b", ms=14, alpha=0.45, label = "Exact enumeration")

ax.set_xticks(np.arange(2, 13, 2))

plt.xlabel("N", fontsize = 24)
plt.ylabel( r"$R_e^2$" , fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 


plt.legend(loc="best", fontsize=20)

plt.savefig("/home/kamilla/Lattice_models/img/endMc08.png")

# %%
results = np.loadtxt("Ising/Calcs_1/Radius_0.800000_0_higher_hpc.txt", skiprows=3)
n_saw = results[:,0]
mean_r = results[:,1]


fig = plt.figure(figsize=(8, 7))
ax = fig.add_subplot(111)
 
#plt.xlim(-1, 21)
#plt.ylim(-1, 65)
plt.title(r"End-to-end distance $R_e^2$", fontsize=24)
plt.errorbar( n_saw[:700:5], mean_r[:700:5] , yerr=results[:700:5,2], fmt=".", c="k",label =  "Monte-Carlo data")

ax.set_xticks(np.arange(0, 701, 100))

plt.xlabel("N", fontsize = 24)
plt.ylabel( r"$R_e^2$" , fontsize=21)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 


plt.legend(loc="best", fontsize=20)

plt.savefig("/home/kamilla/Lattice_models/img/endEE08.png")

# %% [markdown]
# ### Heat capacity

# %%
nmin = 200 
nmax = 400

e = 10

data = np.zeros(( nmax-nmin+1, e ))
 
for i in range(e):
    filename = "Ising/Calcs_1/M_counts_and_contacts_"+str(i/10)+"00000_0_higher_hpc.txt"
    filedata = np.loadtxt(filename, skiprows=2) 
    for N in range(nmin, nmax+1):
        currentdata=filedata[filedata[:,0]==N]     
        data[N-nmin, i] = (currentdata[:,3] - currentdata[:,1]*currentdata[:,1])*(i/10)*(i/10)

# %%
x = np.arange(nmin, nmax+1)
y = np.arange(0, e)/10.0
X, Y = np.meshgrid(x, y)


plt.figure(figsize=(10,5.5))
plt.contourf(y, x,  data[:,:] ,extend='both', cmap = "plasma")
#plt.xlabel(r"$\epsilon_b$", fontsize=20)
plt.xlabel(r"J", fontsize=22)
plt.ylabel("N", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
plt.colorbar()
plt.title('Heat capacity', fontsize=22)

plt.xlim(0.2)

plt.savefig("/home/kamilla/Lattice_models/img/heatcapacityBS.png")

plt.savefig("/home/kamilla/Lattice_models/Seminar_24_02_2020/heatcapacityBS.png")

# %%
#js = np.arange(0.70,0.91,0.01)
js = np.arange(70, 90 )
nmin = 50
nmax = 350

e = 20

data = np.zeros(( nmax-nmin+1, e ))
 
for i in range(e):
    if(i%10==0):
        c =str(js[i]/100)+"0"
    else:
        c = str(js[i]/100) 
    #print(i,c)
    filename = "Ising/Calcs_3/M_counts_and_contacts_"+c+"0000_0_higher_hpc.txt"
    filedata = np.loadtxt(filename, skiprows=2) 
    for N in range(nmin, nmax+1):
        currentdata=filedata[filedata[:,0]==N][0]   
         
            
            
        j=js[i]/100
    
        data[N-nmin, i] = (currentdata[3] - currentdata[1]*currentdata[1])*j*j
        #1.0 -currentdata[11]/3.0/currentdata[9]/currentdata[9]
        #(currentdata[3] - currentdata[1]*currentdata[1])*j*j

# %%
x = np.arange(nmin, nmax+1)
y =js/100.0
X, Y = np.meshgrid(x, y)


plt.figure(figsize=(10,5.5))
 
plt.contourf(y, x,  data[:,:] ,extend='both', cmap = "plasma")

plt.xlim(0.72)
#plt.xlabel(r"$\epsilon_b$", fontsize=20)
plt.xlabel(r"J", fontsize=22)
plt.ylabel("N", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
plt.colorbar()
plt.title('Heat capacity', fontsize=22)


plt.savefig("/home/kamilla/Lattice_models/img/heatcapacityBSshort.png")

# %%
data = np.zeros((e, 14))
N = 101

for i in range(e):
    if (js[i]==82):
        continue
    if(i%10==0):
        c =str(js[i]/100)+"0"
    else:
        c = str(js[i]/100) 
    #print(i,c)
    file  = "Ising/Calcs_3/M_counts_and_contacts_"+c+"0000_0_higher_hpc.txt"
    currentdata = np.genfromtxt(file, max_rows = 1, missing_values = "" )
    data[i][0] = currentdata[0] 
    data[i][1] = currentdata[1]
    
    currentdata = np.genfromtxt(file, skip_header=1,max_rows = 1, missing_values = "" )
    data[i][2] = currentdata[0]
    data[i][3] = currentdata[1]

    filename = "Ising/Calcs_3/M_counts_and_contacts_"+c+"0000_0_higher_hpc.txt" 
    currentdata = np.loadtxt(filename, skiprows=2) 
    #print(i)
    data[i][4] = currentdata[N-1][7] 
    data[i][5] = currentdata[N-1][8] 
    data[i][6] = currentdata[N-1][9]
    data[i][7] = currentdata[N-1][10]
    data[i][8] = currentdata[N-1][11]
    data[i][9] = currentdata[N-1][12]
    data[i][10] = 1.0 - data[i][6]/3.0/data[i][4]/data[i][4]
    data[i][11] = (2* data[i][5]/data[i][4] )**2 + ( data[i][7] /  data[i][6])
    data[i][11] = np.sqrt(data[i][11]) * data[i][10]
    data[i][12] = 1.0 - data[i][8]/3.0/data[i][6]/data[i][6]
    data[i][13] = (2*data[i][7] / data[i][6])**2 + (data[i][9] / data[i][8])
    data[i][13] = np.sqrt(data[i][13]) * data[i][12] 


data70 = data


data = np.zeros((e, 14))
N =201

for i in range(e):
    if (js[i]==82):
        continue
    if(i%10==0):
        c =str(js[i]/100)+"0"
    else:
        c = str(js[i]/100) 
    #print(i,c)
    file  = "Ising/Calcs_3/M_counts_and_contacts_"+c+"0000_0_higher_hpc.txt"
    currentdata = np.genfromtxt(file, max_rows = 1, missing_values = "" )
    data[i][0] = currentdata[0] 
    data[i][1] = currentdata[1]
    
    currentdata = np.genfromtxt(file, skip_header=1,max_rows = 1, missing_values = "" )
    data[i][2] = currentdata[0]
    data[i][3] = currentdata[1]

    filename = "Ising/Calcs_3/M_counts_and_contacts_"+c+"0000_0_higher_hpc.txt" 
    currentdata = np.loadtxt(filename, skiprows=2) 
    #print(i)
    data[i][4] = currentdata[N-1][7] 
    data[i][5] = currentdata[N-1][8] 
    data[i][6] = currentdata[N-1][9]
    data[i][7] = currentdata[N-1][10]
    data[i][8] = currentdata[N-1][11]
    data[i][9] = currentdata[N-1][12]
    data[i][10] = 1.0 - data[i][6]/3.0/data[i][4]/data[i][4]
    #print(data[i][10],data[i][6],data[i][4])
    data[i][11] = (2* data[i][5]/data[i][4] )**2 + ( data[i][7] /  data[i][6])
    data[i][11] = np.sqrt(data[i][11]) * data[i][10]
    data[i][12] = 1.0 - data[i][8]/3.0/data[i][6]/data[i][6]
    data[i][13] = (2*data[i][7] / data[i][6])**2 + (data[i][9] / data[i][8])
    data[i][13] = np.sqrt(data[i][13]) * data[i][12] 


data200 = data

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

 
#plt.errorbar(data400[3:,0], data400[3:,10], yerr=data400[3:,11], fmt = ".", ms=14,c = "indigo",ecolor="purple", label="N = 400")

#plt.errorbar(data200[3:,0], data200[3:,10], yerr=4*data200[3:,11], fmt = ".", ms=14,c = "pink",ecolor="pink", label="N = 200")

#plt.errorbar(data70[3:,0], data70[3:,12], yerr=4*data70[3:,13], fmt = ".", ms=14,c = "grey",  label="N = 70")

plt.errorbar(data70[3:,0], data70[3:,12], fmt = ".", ms=14,c = "grey",  label="N = 100")

plt.errorbar(data200[3:,0], data200[3:,12], fmt = ".", ms=14,c = "pink",ecolor="pink", label="N = 200")


plt.xlim(0.69, 0.91)

plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$U_4$ ", fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
 
plt.legend(loc='best', fontsize=20)


ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,16,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 16, 2)/10), 2) )
# Out:
# [Text(0.0, 1, '1.0'),
#  Text(0.2, 1, '1.22'),
#  Text(0.4, 1, '1.49'),
#  Text(0.6, 1, '1.82'),
#  Text(0.8, 1, '2.23'),
#  Text(1.0, 1, '2.72'),
#  Text(1.2, 1, '3.32'),
#  Text(1.4, 1, '4.06')]

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

 
#plt.errorbar(data400[3:,0], data400[3:,10], yerr=data400[3:,11], fmt = ".", ms=14,c = "indigo",ecolor="purple", label="N = 400")

#plt.errorbar(data200[3:,0], data200[3:,10], yerr=4*data200[3:,11], fmt = ".", ms=14,c = "pink",ecolor="pink", label="N = 200")

#plt.errorbar(data70[3:,0], data70[3:,12], yerr=4*data70[3:,13], fmt = ".", ms=14,c = "grey",  label="N = 70")

plt.errorbar(data70[3:,0], data70[3:,6], yerr=data70[3:,7],fmt = ".", ms=14,c = "grey",  label="N = 70")

plt.errorbar(data200[3:,0], data200[3:,6], yerr=data200[3:,7] , fmt = ".", ms=14,c = "pink",ecolor="pink", label="N = 200")



plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$m_2$ ", fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
 
plt.legend(loc='best', fontsize=20)


ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,16,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 16, 2)/10), 2) )
# Out:
# [Text(0.0, 1, '1.0'),
#  Text(0.2, 1, '1.22'),
#  Text(0.4, 1, '1.49'),
#  Text(0.6, 1, '1.82'),
#  Text(0.8, 1, '2.23'),
#  Text(1.0, 1, '2.72'),
#  Text(1.2, 1, '3.32'),
#  Text(1.4, 1, '4.06')]

# %% [markdown]
# $\nu$

# %%
def r_on_n(n, nu, b):
    
    
    return 2*nu*n+b

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

e = 20

js = np.arange(70, 90 )


v = np.zeros(e)
sigmas = np.zeros(e)
ints = js

k1=1
k2=1

nmin = 70
nmax_1 = 251
for i in range(e):
    
    if(i%10==0):
        c =str(js[i]/100)+"0"
    else:
        c = str(js[i]/100) 
    #print(i,c)
    filename  = "Ising/Calcs_2/Radius_"+c+"0000_0_higher_hpc.txt"
    #currentdata = np.genfromtxt(file, max_rows = 1, missing_values = "" )
    results = np.loadtxt(filename, skiprows=2) 
    results=results[nmin:nmax_1,:]
    n_saw = results[:,0]
    mean_r = results[:,1]
    err_r = results[:,2]    
    popt, pcov = curve_fit(r_on_n, np.log(n_saw+k2), np.log(mean_r+k1), sigma=err_r )  
    v[i] = popt[0]
    perr = np.sqrt(np.diag(pcov))

    sigmas[i] =perr[0]

#ax2.plot(ints/10, v , ".", c="k") 
plt.errorbar( js/100, v , yerr=sigmas, fmt="o", ms = 12,c="k", label = r"Estimated $\nu$")

v_phase=v
err_phase=sigmas

nu_homopolymer = v
#plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.xlabel(r'J', fontsize = 22)
plt.ylabel(r"$\nu$ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#ax.set_xticks(np.arange(0, 1, 0.1))

theta = 1.0/1.18

#plt.plot([theta], [4.0/7.0], "*", c= "purple", ms=15)

plt.legend(loc="best", fontsize=20)

#plt.grid("True")

ax2 = ax.twiny() 
#ax2.set_xlim(0,1)
ax2.set_xlabel(r'$x$', fontsize=22)
#ax2.set_xticks(np.arange(0,10,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(70, 90, 2)/100), 2) )
    
plt.plot([js[0], js[-1]], [4/7, 4/7], "-", label=r"$\nu=\frac{4}{7}$", c="b",lw=4, alpha=0.95)
    
fig.tight_layout()

#plt.savefig("/home/kamilla/Lattice_models/img/nunearjphase.png")
# Out:
# <ipython-input-17-b64a2153944e>:66: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels( np.round( np.exp(np.arange(70, 90, 2)/100), 2) )

# %%
    
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

 

v = np.zeros(10)
sigmas = np.zeros(10)
ints = np.arange(10)

k1=1
k2=1

nmin = 70
nmax_1 = 401
for i in range(10):
    filename ="Ising/Calcs_1/Radius_"+str(i/10)+"00000_0_higher_hpc.txt"
    results = np.loadtxt(filename, skiprows=2) 
    results=results[nmin:nmax_1,:]
    n_saw = results[:,0]
    mean_r = results[:,1]
    err_r = results[:,2]    
    popt, pcov = curve_fit(r_on_n, np.log(n_saw+k2), np.log(mean_r+k1), sigma=err_r )  
    v[i] = popt[0]
    perr = np.sqrt(np.diag(pcov))

    sigmas[i] =perr[0]

#ax2.plot(ints/10, v , ".", c="k") 
plt.errorbar( ints/10, v , yerr=sigmas, fmt="o", ms = 12,c="k", label = r"Estimated $\nu$")
nu_homopolymer = v
#plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.xlabel(r'J', fontsize = 22)
plt.ylabel(r"$\nu$ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
ax.set_xticks(np.arange(0, 1, 0.1))
plt.plot([ints[0]/10 , ints[-1]/10 ], [4/7, 4/7], "-", label=r"$\nu=\frac{4}{7}$", c="b",lw=4, alpha=0.95)
 
    
plt.errorbar( js/100, v_phase , yerr=err_phase, fmt="o", ms = 12,c="k" )
    
theta = 1.0/1.18

#plt.plot([theta], [4.0/7.0], "*", c= "purple", ms=15)

plt.legend(loc="best", fontsize=20)

plt.xlim(0.33)
#plt.grid("True")

ax2 = ax.twiny() 
#ax2.set_xlim(0,1)
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,10,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 10, 2)/10), 2) )
    
    
fig.tight_layout()


plt.savefig("/home/kamilla/Lattice_models/img/nuvsJBS.png")

plt.savefig("/home/kamilla/Lattice_models/Seminar_24_02_2020/nuvsJBS.png")

# %% [markdown]
# M

# %%
nplot = 10 
data = np.zeros(( nmax-nmin+1, nplot , 11 ))

#lengths = [100, 150, 200, 250, 300, 350, 400]

#lengths = [100, 150, 200, 250, 300 ]

lengths = [50, 100, 150, 200, 250 ]

datas = np.zeros((len(lengths), nplot ))
errors = np.zeros((len(lengths), nplot ))
for i in range(nplot ):
    filename = "Ising/Calcs_1/M_counts_and_contacts_"+str(i/10)+"00000_0_higher_hpc.txt"
    filedata = np.loadtxt(filename, skiprows=2)
                         
    
    
    for l in range(len(lengths)):
        currentdata = filedata[lengths[l]-1] #filedata[filedata[:,0]==lengths[l]]
        current = currentdata 
        #datas[l, i] =  current[5] 
        #errors[l,i] =  current[6] 
        datas[l, i] =(currentdata[3] - currentdata[1]*currentdata[1])*(i/10)*(i/10)
        #current[3] - current[1]*current[1]
         
        errors[l,i] = current[4]*current[4] + 4*current[2]*current[2]*currentdata[1]*currentdata[1]
        #current[4]*current[4] + 2*current[2]*current[2] 
        errors[l,i] = np.sqrt(errors[l,i])
    
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

x = np.arange(nplot)/10
for l in range(len(lengths)):
    plt.errorbar(x, datas[l, :], yerr=errors[l,:], fmt="s", ms = 10, label = "N = " + str(lengths[l]))
    

 
plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$ C $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
plt.ylim(-1,600)
  

plt.legend(loc="best", fontsize=20)
 
ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,10,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, nplot, 2)/10), 2) )
# Out:
# [Text(0.0, 1, '1.0'),
#  Text(0.2, 1, '1.22'),
#  Text(0.4, 1, '1.49'),
#  Text(0.6, 1, '1.82'),
#  Text(0.8, 1, '2.23')]

# %%
filename = "Ising/N200.txt"
filedata = np.loadtxt(filename)

     
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

l = 3
plt.errorbar(x, datas[l, :], yerr=errors[l,:], c = "b", fmt="s", ms = 10, label = "N = " + str(lengths[l]) + ", MC, polymer")
    
plt.plot(filedata[:,0],filedata[:,1], c = "b",  ms = 10, label = "N = " + str(lengths[l]) + ", exact, 1D Ising"   )

l=1
plt.errorbar(x, datas[l, :], yerr=errors[l,:], c="red", fmt="s", ms = 10, label = "N = " + str(lengths[l]) + ", MC, polymer")
filename = "Ising/N100.txt"
filedata = np.loadtxt(filename)
    
plt.plot(filedata[:,0],filedata[:,1], c="red",  ms = 10, label = "N = " + str(lengths[l]) + ", exact, 1D Ising"   )
 
    
l=0
plt.errorbar(x, datas[l, :], yerr=errors[l,:], c="pink", fmt="s", ms = 10, label = "N = " + str(lengths[l]) + ", MC, polymer")
filename = "Ising/N50.txt"
filedata = np.loadtxt(filename)
    
plt.plot(filedata[:,0],filedata[:,1], c="pink",  ms = 10, label = "N = " + str(lengths[l]) + ", exact, 1D Ising"   )
     

plt.xlabel(r'J', fontsize = 22)
plt.ylabel(r"$ C $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-1)
  
    
 
js = np.arange(70, 90 )

e = 18

#data = np.zeros(( nmax-nmin+1, e ))
datas = np.zeros((len(lengths), e ))
errors= np.zeros((len(lengths), e ))
for i in range(e):
    if(i%10==0):
        c =str(js[i]/100)+"0"
    else:
        c = str(js[i]/100) 
    #print(i,c)
    filename = "Ising/Calcs_2/M_counts_and_contacts_"+c+"0000_0_higher_hpc.txt" 
    filedata = np.loadtxt(filename, skiprows=2)
    for l in range(len(lengths)):
        currentdata = filedata[lengths[l]-1] #filedata[filedata[:,0]==lengths[l]]
        #print(i, l,js[i], currentdata)
        current = currentdata 
        #datas[l, i] =  current[5] 
        #errors[l,i] =  current[6] 
        datas[l, i] =(currentdata[3] - currentdata[1]*currentdata[1])*(js[i]/100)*(js[i]/100)
        
        #datas[l, i] =(currentdata[3]/N/N - currentdata[1]*currentdata[1]/N/N)*(js[i]/100)*(js[i]/100)
        
        #current[3] - current[1]*current[1]
         
        errors[l,i] = current[4]*current[4] + 4*current[2]*current[2]*currentdata[1]*currentdata[1]
        
        #a = 2*currentdata[3]*current[2]*current[4]/N/N/N
        #errors[l,i] = current[4]*current[4]/N/N + 4*current[2]*current[2]*currentdata[3]*currentdata[3]/N/N/N/N - a
        
        errors[l,i] = np.sqrt(errors[l,i] )    

        
x= js[:e]/100
  
l = 3
plt.errorbar(x, datas[l, :], yerr=errors[l,:],   c="b", fmt="s", ms = 10 )
    
 

l=1
plt.errorbar(x, datas[l, :], yerr=errors[l,:], c="red",fmt="s", ms = 10 )
 
    
l=0
plt.errorbar(x, datas[l, :], yerr=errors[l,:], c="pink", fmt="s", ms = 10 )
    

plt.ylim(0,600)

plt.legend(loc="best", fontsize=20)
 
ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,10,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 10, 2)/10), 2) )


plt.savefig("/home/kamilla/Lattice_models/img/heatsawising.png")

# %% [markdown]
# ## Binders Cumulants

# %%
nplot = 10 
data = np.zeros(( nmax-nmin+1, nplot , 11 ))

#lengths = [100, 150, 200, 250, 300, 350, 400]

#lengths = [100, 150, 200, 250, 300 ]

lengths = [50, 100, 150, 200, 250 ]

datas = np.zeros((len(lengths), nplot ))
errors = np.zeros((len(lengths), nplot ))
for i in range(nplot ):
    filename = "Ising/BC/M_counts_and_contacts_"+str(i/10)+"00000_0_higher_hpc.txt"
    filedata = np.loadtxt(filename, skiprows=2)
                         
    
    
    for l in range(len(lengths)):
        currentdata = filedata[lengths[l]-1] #filedata[filedata[:,0]==lengths[l]]
        current = currentdata 
        #datas[l, i] =  current[5] 
        #errors[l,i] =  current[6] 
        datas[l, i] =1 - currentdata[11]/3/currentdata[9]/currentdata[9]
        #current[3] - current[1]*current[1]
         
        #print(current)
        errors[l,i] = (2*currentdata[10] / currentdata[9])**2 + (currentdata[12] /currentdata[11])
        #print(errors[l,i])
        errors[l,i] = np.sqrt(errors[l,i])
        
  

    
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

x = np.arange(nplot)/10
for l in range(len(lengths)):
    plt.errorbar(x, datas[l, :], yerr=errors[l,:], fmt="s--", ms = 10, label = "N = " + str(lengths[l]))
    

 
plt.xlabel(r'$J$', fontsize = 22)
plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
plt.ylim(-0.02, 0.8)



plt.legend(loc="best", fontsize=20)
 
ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,11,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 11, 2)/10), 1) )

plt.savefig("/home/kamilla/Lattice_models/img/bcfar.png")

# %%
#js = np.arange(0.70,0.91,0.01)
js = np.arange(70, 90 )
nmin = 50
nmax = 350

e = 20

data = np.zeros(( nmax-nmin+1, e ))
 
for i in range(e):
    if(i%10==0):
        c =str(js[i]/100)+"0"
    else:
        c = str(js[i]/100) 
    #print(i,c)
    filename = "Ising/Calcs_3/M_counts_and_contacts_"+c+"0000_0_higher_hpc.txt"
    filedata = np.loadtxt(filename, skiprows=2) 
    for N in range(nmin, nmax+1):
        currentdata=filedata[filedata[:,0]==N][0]   
         
            
            
        j=js[i]/100
    
        data[N-nmin, i] = 1.0 -currentdata[11]/3.0/currentdata[9]/currentdata[9]
        #1.0 -currentdata[11]/3.0/currentdata[9]/currentdata[9]
        #(currentdata[3] - currentdata[1]*currentdata[1])*j*j
        
data[:,12]=(data[:,11]+data[:,13])/2
    
x = np.arange(nmin, nmax+1,20)
y =js/100.0
X, Y = np.meshgrid(x, y)


plt.figure(figsize=(10,5.5))
 
plt.contourf(y, x,  data[::20,:] ,extend='both', cmap = "plasma")

plt.xlim(0.72)
#plt.xlabel(r"$\epsilon_b$", fontsize=20)
plt.xlabel(r"J", fontsize=22)
plt.ylabel("N", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
plt.colorbar()
plt.title('Binder cumulants', fontsize=22)


plt.savefig("/home/kamilla/Lattice_models/img/bccolormap.png")

# %%
nplot = 10 
data = np.zeros(( nmax-nmin+1, nplot , 11 ))

#lengths = [100, 150, 200, 250, 300, 350, 400]

#lengths = [100, 150, 200, 250, 300 ]

lengths = [50, 100, 150, 200, 250 ]

datas = np.zeros((len(lengths), nplot ))
errors = np.zeros((len(lengths), nplot ))
for i in range(nplot ):
    filename = "Ising/Calcs_1/M_counts_and_contacts_"+str(i/10)+"00000_0_higher_hpc.txt"
    filedata = np.loadtxt(filename, skiprows=2)
                         
 
    
    for l in range(len(lengths)):
        currentdata = filedata[lengths[l]-1] #filedata[filedata[:,0]==lengths[l]]
        current = currentdata 
        #datas[l, i] =  current[5] 
        #errors[l,i] =  current[6] 
        datas[l, i] =currentdata[7]   #fix it for new data 
        #current[3] - current[1]*current[1]
         
        errors[l,i] = current[8] 
        #errors[l,i] = np.sqrt(errors[l,i])
        
  

    
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

x = np.arange(nplot)/10
for l in range(len(lengths)):
    plt.errorbar(x, datas[l, :], yerr=errors[l,:], fmt="s", ms = 10, label = "N = " + str(lengths[l]))
    

 
plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$ \langle m^2 \rangle $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-1)
  

plt.legend(loc="best", fontsize=20)
 
ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,10,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, nplot, 2)/10), 2) )



plt.savefig("/home/kamilla/Lattice_models/img/m2.png")

# %%
filename = "Ising/SrNam2-200.txt"
filedata = np.loadtxt(filename)

    
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

l = 3
plt.errorbar(x, datas[l, :], yerr=errors[l,:], fmt="s", ms = 10, label = "N = " + str(lengths[l]) + ", MC, polymer")
    
plt.plot(filedata[:,0],filedata[:,1]/200/200, c = "b",  ms = 10, label = "N = " + str(lengths[l]) + ", exact, 1D Ising"   )

l=1
plt.errorbar(x, datas[l, :], yerr=errors[l,:], fmt="s", ms = 10, label = "N = " + str(lengths[l]) + ", MC, polymer")
filename = "Ising/SrNam2-100.txt"
filedata = np.loadtxt(filename)
    
plt.plot(filedata[:,0],filedata[:,1]/100/100, c="red",  ms = 10, label = "N = " + str(lengths[l]) + ", exact, 1D Ising"   )
 
    
l=0
plt.errorbar(x, datas[l, :] , yerr=errors[l,:], c="pink", fmt="s", ms = 10, label = "N = " + str(lengths[l]) + ", MC, polymer")
filename = "Ising/SrNam2-50.txt"
filedata = np.loadtxt(filename)
    
plt.plot(filedata[:,0],filedata[:,1]/50/50  , c="purple",  ms = 10, label = "N = " + str(lengths[l]) + ", exact, 1D Ising"   )
     

plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$ \langle m^2 \rangle $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-1)
  

plt.legend(loc="best", fontsize=20)
 
ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,10,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, nplot, 2)/10), 2) )


plt.savefig("/home/kamilla/Lattice_models/img/m2sawising.png")

# %%
nplot = 7 
x = np.arange(nplot)/10
data = np.zeros(( nmax-nmin+1, nplot , 11 ))

#lengths = [100, 150, 200, 250, 300, 350, 400]

#lengths = [100, 150, 200, 250, 300 ]

lengths = [50, 100, 150, 200, 250 ]

datas = np.zeros((len(lengths), nplot ))
errors = np.zeros((len(lengths), nplot ))
for i in range(nplot ):
    filename = "Ising/BC/M_counts_and_contacts_"+str(i/10)+"00000_0_higher_hpc.txt"
    filedata = np.loadtxt(filename, skiprows=2)
                         
    
    
    for l in range(len(lengths)):
        currentdata = filedata[lengths[l]-1] #filedata[filedata[:,0]==lengths[l]]
        current = currentdata 
        datas[l, i] =1 - currentdata[11]/3/currentdata[9]/currentdata[9]
        #current[3] - current[1]*current[1]
         
        #print(current)
        errors[l,i] = (2*currentdata[10] / currentdata[9])**2 + (currentdata[12] /currentdata[11])
        #print(errors[l,i])
        errors[l,i] = np.sqrt(errors[l,i])
        #datas[l, i] =  current[5] 
        #errors[l,i] =  current[6] 
        #datas[l, i] =(currentdata[3] - currentdata[1]*currentdata[1])*(i/10)*(i/10)
        #current[3] - current[1]*current[1]
         
        #errors[l,i] = current[4]*current[4] + 4*current[2]*current[2]*currentdata[1]*currentdata[1]
        #current[4]*current[4] + 2*current[2]*current[2] 
        #errors[l,i] = np.sqrt(errors[l,i])
    
    
filename = "Ising/N200.txt"
filedata = np.loadtxt(filename)

     
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

l = 3
plt.errorbar(x, datas[l, :], yerr=errors[l,:], c = "b", fmt="s--", ms = 10, label = "N = " + str(lengths[l]) + ", MC, polymer")
    
#plt.plot(filedata[:,0],filedata[:,1], c = "b",  ms = 10, label = "N = " + str(lengths[l]) + ", exact, 1D Ising"   )

l=1
plt.errorbar(x, datas[l, :], yerr=errors[l,:], c="orange", fmt="s--", ms = 10, label = "N = " + str(lengths[l]) + ", MC, polymer")
filename = "Ising/N100.txt"
filedata = np.loadtxt(filename)
    
#plt.plot(filedata[:,0],filedata[:,1], c="red",  ms = 10, label = "N = " + str(lengths[l]) + ", exact, 1D Ising"   )
 
    
l=0
plt.errorbar(x, datas[l, :], yerr=errors[l,:], c="pink", fmt="s--", ms = 10, label = "N = " + str(lengths[l]) + ", MC, polymer")
filename = "Ising/N50.txt"
filedata = np.loadtxt(filename)
    
#plt.plot(filedata[:,0],filedata[:,1], c="purple",  ms = 10, label = "N = " + str(lengths[l]) + ", exact, 1D Ising"   )
     

plt.xlabel(r'J', fontsize = 22)
plt.ylabel(r"$ U_4 $ ", fontsize=22)
plt.tick_params(axis='x', labelsize=22) 
plt.tick_params(axis='y', labelsize=22) 
#plt.ylim(-1)
  
    
 
js = np.arange(70, 90 )

e = 20

#data = np.zeros(( nmax-nmin+1, e ))
datas = np.zeros((len(lengths), e ))
errors= np.zeros((len(lengths), e ))
for i in range(e):
    if(i%10==0):
        c =str(js[i]/100)+"0"
    else:
        c = str(js[i]/100) 
    #print(i,c)
    filename = "Ising/Calcs_2/M_counts_and_contacts_"+c+"0000_0_higher_hpc.txt" 
    filedata = np.loadtxt(filename, skiprows=2)
    for l in range(len(lengths)):
        currentdata = filedata[lengths[l]-1] #filedata[filedata[:,0]==lengths[l]]
        #print(i, l,js[i], currentdata)
        current = currentdata 
        #datas[l, i] =  current[5] 
        #errors[l,i] =  current[6] 
        datas[l, i] =1 - currentdata[11]/3/currentdata[9]/currentdata[9]
        if (datas[l, i] ==1):
            datas[l, i] = np.nan
        
        #current[3] - current[1]*current[1]
         
        #print(current)
        errors[l,i] = (2*currentdata[10] / currentdata[9])**2 + (currentdata[12] /currentdata[11])
        #print(errors[l,i])
        errors[l,i] = np.sqrt(errors[l,i]) * datas[l, i]

        
x= js[:e]/100
  
l = 3
plt.errorbar(x, datas[l, :], yerr=errors[l,:],   c="b", fmt="s--", ms = 10 )
    
 

l=1
plt.errorbar(x, datas[l, :], yerr=errors[l,:], c="orange",fmt="s--", ms = 10 )
 
    
l=0
plt.errorbar(x, datas[l, :], yerr=errors[l,:], c="pink", fmt="s--", ms = 10 )
    
plt.xlim(0.75, 0.9)
plt.ylim(0.1,0.68)

plt.legend(loc="best", fontsize=20)
 
ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,10,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 10, 2)/10), 1) )


plt.savefig("/home/kamilla/Lattice_models/img/allbc.png")
