# %%
from pathlib import Path
from collections import Counter

# %%
import matplotlib.pyplot as plt
import random
import numpy as np
import pandas as pd
from matplotlib.ticker import LogFormatter 
from scipy.optimize import curve_fit
from pathlib import Path
import matplotlib.colors
from matplotlib import ticker, cm
# %matplotlib notebook

# %% [markdown]
# # Grand canonical
# ## N = 400

# %%
N = 400
data = np.zeros((16, 14))
for i in range(16):
    file = "HP_simulations/Main_Simulations/counts_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.genfromtxt(file, max_rows = 6, missing_values = "" )
    data[i][0] = currentdata[0][0]
    data[i][1] = currentdata[0][1]
    data[i][2] = currentdata[1][0]
    data[i][3] = currentdata[1][1]
    
    filename = "HP_simulations/Main_Simulations/mags_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.loadtxt(filename, skiprows=1) 
    data[i][4] = currentdata[N-1][1] 
    data[i][5] = currentdata[N-1][2] 
    data[i][6] = currentdata[N-1][3]
    data[i][7] = currentdata[N-1][4]
    data[i][8] = currentdata[N-1][5]
    data[i][9] = currentdata[N-1][6]
    data[i][10] = 1.0 - data[i][6]/3.0/data[i][4]/data[i][4]
    data[i][11] = (2* data[i][5]/data[i][4] )**2 + ( data[i][7] /  data[i][6])
    data[i][11] = np.sqrt(data[i][11]) * data[i][10]
    data[i][12] = 1.0 - data[i][8]/3.0/data[i][6]/data[i][6]
    data[i][13] = (2*data[i][7] / data[i][6])**2 + (data[i][9] / data[i][8])
    data[i][13] = np.sqrt(data[i][13]) * data[i][12] 
    print(data[i][6]**2, data[i][8])
    
 

data400 = data 

data = np.zeros((17, 14))
N = 200 
for i in range(17):
    file = "HP_simulations/Main_Simulations/counts_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.genfromtxt(file, max_rows = 6, missing_values = "" )
    data[i][0] = currentdata[0][0]
    data[i][1] = currentdata[0][1]
    data[i][2] = currentdata[1][0]
    data[i][3] = currentdata[1][1]
    
    filename = "HP_simulations/Main_Simulations/mags_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.loadtxt(filename, skiprows=1) 
    data[i][4] = currentdata[N-1][1] 
    data[i][5] = currentdata[N-1][2] 
    data[i][6] = currentdata[N-1][3]
    data[i][7] = currentdata[N-1][4]
    data[i][8] = currentdata[N-1][5]
    data[i][9] = currentdata[N-1][6]
    data[i][10] = 1.0 - data[i][6]/3.0/data[i][4]/data[i][4]
    data[i][11] = (2* data[i][5]/data[i][4] )**2 + ( data[i][7] /  data[i][6])
    data[i][11] = np.sqrt(data[i][11]) * data[i][10]
    data[i][12] = 1.0 - data[i][8]/3.0/data[i][6]/data[i][6]
    data[i][13] = (2*data[i][7] / data[i][6])**2 + (data[i][9] / data[i][8])
    data[i][13] = np.sqrt(data[i][13]) * data[i][12] 


data200 = data
    

data = np.zeros((17, 14))
N = 70 
for i in range(17):
    file = "HP_simulations/Main_Simulations/counts_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.genfromtxt(file, max_rows = 6, missing_values = "" )
    data[i][0] = currentdata[0][0]
    data[i][1] = currentdata[0][1]
    data[i][2] = currentdata[1][0]
    data[i][3] = currentdata[1][1]
    
    filename = "HP_simulations/Main_Simulations/mags_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.loadtxt(filename, skiprows=1) 
    data[i][4] = currentdata[N-1][1] 
    data[i][5] = currentdata[N-1][2] 
    data[i][6] = currentdata[N-1][3]
    data[i][7] = currentdata[N-1][4]
    data[i][8] = currentdata[N-1][5]
    data[i][9] = currentdata[N-1][6]
    data[i][10] = 1.0 - data[i][6]/3.0/data[i][4]/data[i][4]
    data[i][11] = (2* data[i][5]/data[i][4] )**2 + ( data[i][7] /  data[i][6])
    data[i][11] = np.sqrt(data[i][11]) * data[i][10]
    data[i][12] = 1.0 - data[i][8]/3.0/data[i][6]/data[i][6]
    data[i][13] = (2*data[i][7] / data[i][6])**2 + (data[i][9] / data[i][8])
    data[i][13] = np.sqrt(data[i][13]) * data[i][12] 


data70 = data
# Out:
# 0.06270466728099999 0.0633205
# 0.06519749424400001 0.0658416
# 0.06753397612900001 0.0682082
# 0.070625720025 0.0713218
# 0.07436256302500001 0.0750745
# 0.07881887800900002 0.0795683
# 0.08456405840099998 0.0853661
# 0.09186718521599999 0.0927087
# 0.10131998286399999 0.102269
# 0.11438668052099998 0.115414
# 0.132601581025 0.133793
# 0.16176242680900002 0.163247
# 0.20856758286399998 0.210366
# 0.28741822099599995 0.289851
# 0.379879926336 0.381828
# 0.4884891664 0.489157

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

 
plt.errorbar(data400[:,0], data400[:,4], yerr=4*data400[:,5], fmt = "s", ms=14,c = "indigo",ecolor="indigo", label="N = 400")


plt.errorbar(data200[:,0], data200[:,4], yerr=4*data200[:,5], fmt = ".", ms=14,c = "pink",ecolor="pink", label="N = 200")

plt.errorbar(data70[:,0], data70[:,4], yerr=4*data70[:,5], fmt = ".", ms=14,c = "grey",  label="N = 70")


plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$\langle M\rangle$ ", fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
 
plt.legend(loc='best', fontsize=20)


ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,17,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 17, 2)/10), 2) )


#plt.savefig("/home/kamilla/SAWs/Bachelor thesis/img/mean_mag.png")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# [Text(0.0, 1, '1.0'),
#  Text(0.2, 1, '1.22'),
#  Text(0.4, 1, '1.49'),
#  Text(0.6, 1, '1.82'),
#  Text(0.8, 1, '2.23'),
#  Text(1.0, 1, '2.72'),
#  Text(1.2, 1, '3.32'),
#  Text(1.4, 1, '4.06'),
#  Text(1.6, 1, '4.95')]

# %%
#второй момент 

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

 
plt.errorbar(data400[:,0], data400[:,6], yerr=4*data400[:,5], fmt = "s", ms=14,c = "indigo",ecolor="indigo", label="N = 400")


plt.errorbar(data200[:,0], data200[:,6], yerr=4*data200[:,5], fmt = ".", ms=14,c = "pink",ecolor="pink", label="N = 200")

plt.errorbar(data70[:,0], data70[:,6], yerr=4*data70[:,5], fmt = ".", ms=14,c = "grey",  label="N = 70")




plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$\langle M\rangle$ ", fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
 
plt.legend(loc='best', fontsize=20)


ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,17,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 17, 2)/10), 2) )
# Out:
# <img src="data:image/png;base64,..." width="1000">
# [Text(0.0, 1, '1.0'),
#  Text(0.2, 1, '1.22'),
#  Text(0.4, 1, '1.49'),
#  Text(0.6, 1, '1.82'),
#  Text(0.8, 1, '2.23'),
#  Text(1.0, 1, '2.72'),
#  Text(1.2, 1, '3.32'),
#  Text(1.4, 1, '4.06'),
#  Text(1.6, 1, '4.95')]

# %%
#второй момент 

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

 
plt.errorbar(data400[:,0], data400[:,8], yerr=4*data400[:,5], fmt = "s", ms=14,c = "indigo",ecolor="indigo", label="N = 400")

plt.errorbar(data200[:,0], data200[:,8], yerr=4*data200[:,5], fmt = ".", ms=14,c = "pink",ecolor="pink", label="N = 200")

plt.errorbar(data70[:,0], data70[:,8], yerr=4*data70[:,5], fmt = ".", ms=14,c = "grey",  label="N = 70")




plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$\langle M\rangle$ ", fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
 
plt.legend(loc='best', fontsize=20)


ax2 = ax.twiny() 

ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,17,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 17, 2)/10), 2) )
# Out:
# <img src="data:image/png;base64,..." width="1000">
# [Text(0.0, 1, '1.0'),
#  Text(0.2, 1, '1.22'),
#  Text(0.4, 1, '1.49'),
#  Text(0.6, 1, '1.82'),
#  Text(0.8, 1, '2.23'),
#  Text(1.0, 1, '2.72'),
#  Text(1.2, 1, '3.32'),
#  Text(1.4, 1, '4.06'),
#  Text(1.6, 1, '4.95')]

# %%
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111)

 
plt.errorbar(data400[3:,0], data400[3:,10], yerr=data400[3:,11], fmt = ".", ms=14,c = "indigo",ecolor="purple", label="N = 400")

plt.errorbar(data200[3:,0], data200[3:,10], yerr=4*data200[3:,11], fmt = ".", ms=14,c = "pink",ecolor="pink", label="N = 200")

plt.errorbar(data70[3:,0], data70[3:,10], yerr=4*data70[3:,11], fmt = ".", ms=14,c = "grey",  label="N = 70")


plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$U_2$ ", fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
 
plt.legend(loc='best', fontsize=20)


ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,16,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 16, 2)/10), 2) )


plt.savefig("/home/kamilla/SAWs/Bachelor thesis/img/u2.png")

# %%
data = np.zeros((17, 15))
i=0
for file in Path("HP_simulations/Main_Simulations/").glob('counts_hp*.txt'):
    currentdata = np.genfromtxt(file, max_rows = 6, missing_values = "" )
    data[i][0] = currentdata[0][0]
    data[i][1] = currentdata[0][1]
    data[i][2] = currentdata[1][0]
    data[i][3] = currentdata[1][1]
    data[i][4] = currentdata[5][0]
    data[i][5] = currentdata[5][1]
    data[i][14] = currentdata[4][0]  #
    currentdata = np.genfromtxt(file, max_rows = 2, skip_header=6 )
    data[i][6] = currentdata[0][0]
    data[i][7] = currentdata[0][1]
    data[i][8] = currentdata[1][0]
    data[i][9] = currentdata[1][1]
    data[i][10] = 1.0 - data[i][6]/3.0/data[i][4]/data[i][4]
    data[i][11] = (2* data[i][5]/data[i][4] )**2 + ( data[i][7] /  data[i][6])
    data[i][11] = np.sqrt(data[i][11]) * data[i][10]
    data[i][12] = 1.0 - data[i][8]/3.0/data[i][6]/data[i][6]
    data[i][13] = (2*data[i][7] / data[i][6])**2 + (data[i][9] / data[i][8])
    data[i][13] = np.sqrt(data[i][13]) * data[i][12]    

    
    i=i+1

# %%
fig = plt.figure(figsize=(13, 8))
ax = fig.add_subplot(111)

 
plt.errorbar(data[:,0], data[:,4], yerr=data[:,5], fmt = ".", ms=14,c = "indigo",ecolor="purple", label="Monte-Carlo Data")
plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$\langle M\rangle$ ", fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
 
plt.legend(loc='best', fontsize=20)


ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,16,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 16, 2)/10), 2) )


plt.savefig("/home/kamilla/SAWs/Bachelor thesis/img/mean_mag.png")

# %%
fig = plt.figure(figsize=(13, 8))
ax = fig.add_subplot(111)

 
plt.errorbar(data[:,0], data[:,14]/data[:,2], yerr=data[:,5], fmt = ".", ms=14,c = "indigo",ecolor="purple", label="Monte-Carlo Data")
plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$\langle M^2 \rangle -\langle M  \rangle^2  $  ", fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
 
plt.legend(loc='best', fontsize=20)


ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,16,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 16, 2)/10), 2) )
# Out:
# [Text(0, 1, '1.0'),
#  Text(0, 1, '1.22'),
#  Text(0, 1, '1.49'),
#  Text(0, 1, '1.82'),
#  Text(0, 1, '2.23'),
#  Text(0, 1, '2.72'),
#  Text(0, 1, '3.32'),
#  Text(0, 1, '4.06')]

# %%
N = 100
data = np.zeros((16, 14))
for i in range(16):
    file = "HP_simulations/Main_Simulations/counts_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.genfromtxt(file, max_rows = 6, missing_values = "" )
    data[i][0] = currentdata[0][0]
    data[i][1] = currentdata[0][1]
    data[i][2] = currentdata[1][0]
    data[i][3] = currentdata[1][1]
    
    filename = "HP_simulations/Main_Simulations/mags_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.loadtxt(filename, skiprows=1) 
    data[i][4] = currentdata[N-1][1] 
    data[i][5] = currentdata[N-1][2] 
    data[i][6] = currentdata[N-1][3]
    data[i][7] = currentdata[N-1][4]
    data[i][8] = currentdata[N-1][5]
    data[i][9] = currentdata[N-1][6]
    data[i][10] = 1.0 - data[i][6]/3.0/data[i][4]/data[i][4]
    data[i][11] = (2* data[i][5]/data[i][4] )**2 + ( data[i][7] /  data[i][6])
    data[i][11] = np.sqrt(data[i][11]) * data[i][10]
    data[i][12] = 1.0 - data[i][8]/3.0/data[i][6]/data[i][6]
    data[i][13] = (2*data[i][7] / data[i][6])**2 + (data[i][9] / data[i][8])
    data[i][13] = np.sqrt(data[i][13]) * data[i][12] 
    print(data[i][6]**2, data[i][8])
    
 

data400 = data 

data = np.zeros((17, 14))
N = 200 
for i in range(17):
    file = "HP_simulations/Main_Simulations/counts_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.genfromtxt(file, max_rows = 6, missing_values = "" )
    data[i][0] = currentdata[0][0]
    data[i][1] = currentdata[0][1]
    data[i][2] = currentdata[1][0]
    data[i][3] = currentdata[1][1]
    
    filename = "HP_simulations/Main_Simulations/mags_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.loadtxt(filename, skiprows=1) 
    data[i][4] = currentdata[N-1][1] 
    data[i][5] = currentdata[N-1][2] 
    data[i][6] = currentdata[N-1][3]
    data[i][7] = currentdata[N-1][4]
    data[i][8] = currentdata[N-1][5]
    data[i][9] = currentdata[N-1][6]
    data[i][10] = 1.0 - data[i][6]/3.0/data[i][4]/data[i][4]
    data[i][11] = (2* data[i][5]/data[i][4] )**2 + ( data[i][7] /  data[i][6])
    data[i][11] = np.sqrt(data[i][11]) * data[i][10]
    data[i][12] = 1.0 - data[i][8]/3.0/data[i][6]/data[i][6]
    data[i][13] = (2*data[i][7] / data[i][6])**2 + (data[i][9] / data[i][8])
    data[i][13] = np.sqrt(data[i][13]) * data[i][12] 


data200 = data
    

data = np.zeros((17, 14))
N = 70 
for i in range(17):
    file = "HP_simulations/Main_Simulations/counts_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.genfromtxt(file, max_rows = 6, missing_values = "" )
    data[i][0] = currentdata[0][0]
    data[i][1] = currentdata[0][1]
    data[i][2] = currentdata[1][0]
    data[i][3] = currentdata[1][1]
    
    filename = "HP_simulations/Main_Simulations/mags_hp_moresteps_"+str(i/10)+"00000_higher_hpc.txt"
    currentdata = np.loadtxt(filename, skiprows=1) 
    data[i][4] = currentdata[N-1][1] 
    data[i][5] = currentdata[N-1][2] 
    data[i][6] = currentdata[N-1][3]
    data[i][7] = currentdata[N-1][4]
    data[i][8] = currentdata[N-1][5]
    data[i][9] = currentdata[N-1][6]
    data[i][10] = 1.0 - data[i][6]/3.0/data[i][4]/data[i][4]
    data[i][11] = (2* data[i][5]/data[i][4] )**2 + ( data[i][7] /  data[i][6])
    data[i][11] = np.sqrt(data[i][11]) * data[i][10]
    data[i][12] = 1.0 - data[i][8]/3.0/data[i][6]/data[i][6]
    data[i][13] = (2*data[i][7] / data[i][6])**2 + (data[i][9] / data[i][8])
    data[i][13] = np.sqrt(data[i][13]) * data[i][12] 


data70 = data
# Out:
# 0.06373605160000001 0.0662518
# 0.065991958321 0.0685623
# 0.068424619561 0.0710564
# 0.07129647619599999 0.0740339
# 0.075225678529 0.0780774
# 0.079697806864 0.0826787
# 0.085148407204 0.0883042
# 0.09224887562500002 0.0956283
# 0.101503411216 0.105164
# 0.11370451440099998 0.117754
# 0.13079723228100001 0.13538
# 0.1545118864 0.159816
# 0.188941486276 0.195098
# 0.2369547684 0.243744
# 0.2978321476 0.304681
# 0.35925878192399996 0.365411

# %%
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111)

 
plt.errorbar(data400[:,0], data400[:,4], yerr=4*data400[:,5], fmt = "s", ms=14,c = "indigo",ecolor="indigo", label="N = 100")


plt.errorbar(data200[:,0], data200[:,4], yerr=4*data200[:,5], fmt = ".", ms=14,c = "pink",ecolor="pink", label="N = 200")

plt.errorbar(data70[:,0], data70[:,4], yerr=4*data70[:,5], fmt = ".", ms=14,c = "grey",  label="N = 70")


plt.xlabel(r'$\epsilon_b$', fontsize = 22)
plt.ylabel(r"$\langle M\rangle$ ", fontsize=20)
plt.tick_params(axis='x', labelsize=20) 
plt.tick_params(axis='y', labelsize=20) 
 
plt.legend(loc='best', fontsize=20)


ax2 = ax.twiny() 
ax2.set_xlabel(r'$x$', fontsize=22)
ax2.set_xticks(np.arange(0,17,2)/10)
ax2.tick_params(axis='x', labelsize=22)
ax2.set_xbound(ax.get_xbound())
ax2.set_xticklabels( np.round( np.exp(np.arange(0, 17, 2)/10), 2) )
# Out:
# <img src="data:image/png;base64,..." width="1000">
# [Text(0.0, 1, '1.0'),
#  Text(0.2, 1, '1.22'),
#  Text(0.4, 1, '1.49'),
#  Text(0.6, 1, '1.82'),
#  Text(0.8, 1, '2.23'),
#  Text(1.0, 1, '2.72'),
#  Text(1.2, 1, '3.32'),
#  Text(1.4, 1, '4.06'),
#  Text(1.6, 1, '4.95')]
